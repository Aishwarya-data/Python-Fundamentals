# %% [markdown]
# ### A variable is a name used to store data in memory so it can be used later in a program.
#
# #### variable_name = value
#
# ##### Rules:
# * start with letter or _
# * use undersore inbetween no space eg: emp_name
# * cannot start with number

# %% [markdown]
# #### 1.Variable Assignment:

# %%
x=123 #integer
y=3.14 #float
z="Variable" #string
is_active=True #Boolean

# %%
name = "Aishwarya"
age = 25
salary = 100000
city = "chennai"
print(name,age,salary,city)
# Out:
# Aishwarya 25 100000 chennai

# %% [markdown]
# #### 2.Dynamic Typing - we can reassign variables to different values.

# %%
Num1 = 12
Num1="I am a data scientist"
print(Num1)
# Out:
# I am a data scientist

# %% [markdown]
# #### 3.Multiple Assignment:

# %%
a,b,c=1,2,3 #Assign Multiple Variables in One Line
x=y=z = 12 #Same Value to Multiple Variables
print(a,b,c)
print(x,y,z)
# Out:
# 1 2 3
# 12 12 12

# %% [markdown]
# #### 4.Addition of two numbers:

# %%
print("Addition of two numbers:")
Num1 = 24
Num2 = 15
sum = Num1+Num2
print("The addition of two numbers is : " , sum)
# Out:
# Addition of two numbers:
# The addition of two numbers is :  39

# %% [markdown]
# #### 5.Taking Input from user -- input function

# %%
#numrical input
Num1 = int(input("Enter the number 1 :"))
Num2 = int(input("Enter the number 2 :"))
sum = Num1+Num2     
print("The Addition of Two Numbers are ",sum)
# Out:
# Enter the number 1 : 24
# Enter the number 2 : 15
# The Addition of Two Numbers are  39

# %%
# string input
str_input = input("Enter your good name:")
# Out:
# Enter your good name: Aishwarya

# %%
#float
Num1 = float(input("Enter the number 1 :"))
Num2 = float(input("Enter the number 2 :"))
sum = Num1+Num2     
print("The Addition of Two Numbers are ",sum)
# Out:
# Enter the number 1 : 2.4
# Enter the number 2 : 1.5
# The Addition of Two Numbers are  3.9

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
